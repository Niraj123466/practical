# %% [markdown]
# # Title : Analyzing Sales Data from Multiple File Formats

# %%
import pandas as pd
import numpy as np

# %%
# !pip install openpyxl
# !pip install xlrd
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df1 = pd.read_csv("sales_data_sample.csv",encoding="cp1252")

# %%
df2 = pd.read_excel("Sample-Sales-Data.xlsx")

# %%
df3 = pd.read_json("customers.json")

# %%
df1.dropna()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10          10223               37     100.00                1  3965.66
# 21          10361               20      72.55               13  1451.00
# 40          10270               21     100.00                9  4905.39
# 47          10347               30     100.00                1  3944.70
# 51          10391               24     100.00                4  2416.56
# ...           ...              ...        ...              ...      ...
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
# 2685        10361               44     100.00               10  5001.92
# 2764        10361               35     100.00               11  4277.35
# 2791        10361               23      95.20               12  2189.60
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df1.drop_duplicates()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df2.dropna()
# Out:
#      Postcode  Sales_Rep_ID Sales_Rep_Name  Year         Value
# 0        2121           456           Jane  2011  84219.497311
# 1        2092           789         Ashish  2012  28322.192268
# 2        2128           456           Jane  2013  81878.997241
# 3        2073           123           John  2011  44491.142121
# 4        2134           789         Ashish  2012  71837.720959
# ..        ...           ...            ...   ...           ...
# 385      2164           123           John  2012  88884.535217
# 386      2193           456           Jane  2013  79440.290813
# 387      2031           123           John  2011  65643.689454
# 388      2130           456           Jane  2012  66247.874869
# 389      2116           456           Jane  2013   3195.699054
#
# [390 rows x 5 columns]

# %%
df2.drop_duplicates()
# Out:
#      Postcode  Sales_Rep_ID Sales_Rep_Name  Year         Value
# 0        2121           456           Jane  2011  84219.497311
# 1        2092           789         Ashish  2012  28322.192268
# 2        2128           456           Jane  2013  81878.997241
# 3        2073           123           John  2011  44491.142121
# 4        2134           789         Ashish  2012  71837.720959
# ..        ...           ...            ...   ...           ...
# 385      2164           123           John  2012  88884.535217
# 386      2193           456           Jane  2013  79440.290813
# 387      2031           123           John  2011  65643.689454
# 388      2130           456           Jane  2012  66247.874869
# 389      2116           456           Jane  2013   3195.699054
#
# [390 rows x 5 columns]

# %%
df3.dropna()
# Out:
#         id                          email       first      last  \
# 0        1         isidro_von@hotmail.com      Torrey      Veum
# 1        2         frederique19@gmail.com       Micah   Sanford
# 2        3              fredy54@gmail.com      Hollis     Swift
# 3        4          braxton29@hotmail.com       Perry   Leffler
# 4        5             turner59@gmail.com     Janelle   Hagenes
# ...    ...                            ...         ...       ...
# 9994  9995  delores_cruickshank@gmail.com      Robert      Batz
# 9995  9996     marley_brown32@hotmail.com       Leone   Reinger
# 9996  9997          raymond68@hotmail.com  Clementina      Bode
# 9997  9998   juston_powlowski@hotmail.com      Yvonne  Prosacco
# 9998  9999       orion.senger72@yahoo.com      Darrin  Connelly
#
#                              company                       created_at  \
# 0             Hilll, Mayert and Wolf 2014-12-25 04:06:27.981000+00:00
# ...

# %%
df3.drop_duplicates()
# Out:
#         id                          email       first      last  \
# 0        1         isidro_von@hotmail.com      Torrey      Veum
# 1        2         frederique19@gmail.com       Micah   Sanford
# 2        3              fredy54@gmail.com      Hollis     Swift
# 3        4          braxton29@hotmail.com       Perry   Leffler
# 4        5             turner59@gmail.com     Janelle   Hagenes
# ...    ...                            ...         ...       ...
# 9994  9995  delores_cruickshank@gmail.com      Robert      Batz
# 9995  9996     marley_brown32@hotmail.com       Leone   Reinger
# 9996  9997          raymond68@hotmail.com  Clementina      Bode
# 9997  9998   juston_powlowski@hotmail.com      Yvonne  Prosacco
# 9998  9999       orion.senger72@yahoo.com      Darrin  Connelly
#
#                              company                       created_at  \
# 0             Hilll, Mayert and Wolf 2014-12-25 04:06:27.981000+00:00
# ...

# %%
unified_data = pd.concat([df1,df2,df3],ignore_index = True)

# %%
unified_data
# Out:
#        ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0          10107.0             30.0      95.70              2.0  2871.00
# 1          10121.0             34.0      81.35              5.0  2765.90
# 2          10134.0             41.0      94.74              2.0  3884.34
# 3          10145.0             45.0      83.26              6.0  3746.70
# 4          10159.0             49.0     100.00             14.0  5205.27
# ...            ...              ...        ...              ...      ...
# 13207          NaN              NaN        NaN              NaN      NaN
# 13208          NaN              NaN        NaN              NaN      NaN
# 13209          NaN              NaN        NaN              NaN      NaN
# 13210          NaN              NaN        NaN              NaN      NaN
# 13211          NaN              NaN        NaN              NaN      NaN
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
unified_data
# Out:
#        ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0          10107.0             30.0      95.70              2.0  2871.00
# 1          10121.0             34.0      81.35              5.0  2765.90
# 2          10134.0             41.0      94.74              2.0  3884.34
# 3          10145.0             45.0      83.26              6.0  3746.70
# 4          10159.0             49.0     100.00             14.0  5205.27
# ...            ...              ...        ...              ...      ...
# 13207          NaN              NaN        NaN              NaN      NaN
# 13208          NaN              NaN        NaN              NaN      NaN
# 13209          NaN              NaN        NaN              NaN      NaN
# 13210          NaN              NaN        NaN              NaN      NaN
# 13211          NaN              NaN        NaN              NaN      NaN
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
sales_trend = unified_data.groupby("YEAR_ID")["SALES"].sum()

# %%
sales_trend
# Out:
# YEAR_ID
# 2003.0    3516979.54
# 2004.0    4724162.60
# 2005.0    1791486.71
# Name: SALES, dtype: float64

# %%
sales_trend_date = unified_data.groupby("ORDERDATE")["SALES"].sum()

# %%
sales_trend_date
# Out:
# ORDERDATE
# 1/10/2003 0:00     6864.05
# 1/10/2005 0:00    16628.16
# 1/12/2004 0:00    50490.64
# 1/12/2005 0:00    44273.36
# 1/15/2004 0:00    51172.65
#                     ...
# 9/30/2004 0:00    42744.06
# 9/5/2003 0:00     34992.40
# 9/7/2004 0:00      7673.38
# 9/8/2004 0:00     93717.43
# 9/9/2004 0:00     38039.00
# Name: SALES, Length: 252, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales = unified_data["SALES"]
year = unified_data["YEAR_ID"]
plt.bar(year,sales)
plt.title("sales vs year")
plt.xlabel("year")
plt.ylabel("sales")
plt.show()

# %%
orderdate=unified_data["ORDERDATE"]
plt.scatter(sales,year)
plt.xlabel("sales")
plt.ylabel("years")
plt.show()

# %%
df1.groupby("COUNTRY")["SALES"].sum().plot(kind = "pie",figsize = (5,5))
plt.show()
